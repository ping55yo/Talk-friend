# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/ping55yo/Talk-friend/master/TempleAmnatCharoen2.csv')
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>District</th>
#       <th>Temple</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>เมือง</td>
#       <td>133</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>เสนางคนิคม</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ลืออำนาจ</td>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ชานุมาน</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>พนา</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>หัวตะพาน</td>
#       <td>60</td>
#     </tr>
#     <tr>
# ...

# %%
df.sort_values('Temple',inplace=True)
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>District</th>
#       <th>Temple</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>ชานุมาน</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>เสนางคนิคม</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>พนา</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ลืออำนาจ</td>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>ปทุมราชวงศา</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>หัวตะพาน</td>
#       <td>60</td>
#     </tr>
#     <tr>
# ...

# %%
plt.rcParams ['font.family']='Tahoma'
plt.bar(df['District'],df['Temple'])
plt.show()
